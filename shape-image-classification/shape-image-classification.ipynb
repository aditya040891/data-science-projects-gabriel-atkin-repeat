# %% [markdown]
# ## Shape Image Classification
#
# Given *images of shapes*, let's try to predict which **shape** is present in a given image.
#
# We will use a TensorFlow/Keras convolutional neural networks to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/cactus3/basicshapes

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

from sklearn.model_selection import train_test_split

import tensorflow as tf

# %%
image_dir = Path('archive/shapes/')

# %% [markdown]
# ### Creating File DataFrame

# %%
filepaths = list(image_dir.glob(r'**/*.png'))
filepaths
# Out:
# [PosixPath('archive/shapes/triangles/drawing(47).png'),
#  PosixPath('archive/shapes/triangles/drawing(3).png'),
#  PosixPath('archive/shapes/triangles/drawing(36).png'),
#  PosixPath('archive/shapes/triangles/drawing(100).png'),
#  PosixPath('archive/shapes/triangles/drawing(98).png'),
#  PosixPath('archive/shapes/triangles/drawing(65).png'),
#  PosixPath('archive/shapes/triangles/drawing(90).png'),
#  PosixPath('archive/shapes/triangles/drawing(19).png'),
#  PosixPath('archive/shapes/triangles/drawing(9).png'),
#  PosixPath('archive/shapes/triangles/drawing(92).png'),
#  PosixPath('archive/shapes/triangles/drawing(5).png'),
#  PosixPath('archive/shapes/triangles/drawing(50).png'),
#  PosixPath('archive/shapes/triangles/drawing(86).png'),
#  PosixPath('archive/shapes/triangles/drawing(83).png'),
#  PosixPath('archive/shapes/triangles/drawing(95).png'),
#  PosixPath('archive/shapes/triangles/drawing(87).png'),
#  PosixPath('archive/shapes/triangles/drawing(35).png'),
#  PosixPath('archive/shapes/triangles/drawing(11).png'),
#  PosixPath('archive/shapes/triangles/drawing(89).png'),
#  PosixPath('archive/shapes/triangles/drawing(41).png'),
#  PosixPath('archive/shapes/triangles/drawing(79).png'),
#  PosixPath('archive/shapes/triangles/drawing(78).png'),
#  PosixPath('archive/shapes/triangles/drawing(81).png'),
#  PosixPath('archive/shapes/triangles/drawing(85).png'),
#  PosixPath('archive/shapes/triangles/drawing(21).png'),
#  PosixPath('archive/shapes/triangles/drawing(22).png'),
#  PosixPath('archive/shapes/triangles/drawing(45).png'),
#  PosixPath('archive/shapes/triangles/drawing(48).png'),
#  PosixPath('archive/shapes/triangles/drawing(26).png'),
#  PosixPath('archive/shapes/triangles/drawing(64).png'),
#  PosixPath('archive/shapes/triangles/drawing(96).png'),
#  PosixPath('archive/shapes/triangles/drawing(76).png'),
#  PosixPath('archive/shapes/triangles/drawing(2).png'),
#  PosixPath('archive/shapes/triangles/drawing(60).png'),
#  PosixPath('archive/shapes/triangles/drawing(71).png'),
#  PosixPath('archive/shapes/triangles/drawing(39).png'),
#  PosixPath('archive/shapes/triangles/drawing(34).png'),
#  PosixPath('archive/shapes/triangles/drawing(33).png'),
#  PosixPath('archive/shapes/triangles/drawing(10).png'),
#  PosixPath('archive/shapes/triangles/drawing(25).png'),
#  PosixPath('archive/shapes/triangles/drawing(91).png'),
#  PosixPath('archive/shapes/triangles/drawing(57).png'),
#  PosixPath('archive/shapes/triangles/drawing(27).png'),
#  PosixPath('archive/shapes/triangles/drawing(52).png'),
#  PosixPath('archive/shapes/triangles/drawing(51).png'),
#  PosixPath('archive/shapes/triangles/drawing(59).png'),
#  PosixPath('archive/shapes/triangles/drawing(14).png'),
#  PosixPath('archive/shapes/triangles/drawing(56).png'),
#  PosixPath('archive/shapes/triangles/drawing(77).png'),
#  PosixPath('archive/shapes/triangles/drawing(29).png'),
#  PosixPath('archive/shapes/triangles/drawing(75).png'),
#  PosixPath('archive/shapes/triangles/drawing(62).png'),
#  PosixPath('archive/shapes/triangles/drawing(94).png'),
#  PosixPath('archive/shapes/triangles/drawing(1).png'),
#  PosixPath('archive/shapes/triangles/drawing(24).png'),
#  PosixPath('archive/shapes/triangles/drawing(58).png'),
#  PosixPath('archive/shapes/triangles/drawing(61).png'),
#  PosixPath('archive/shapes/triangles/drawing(32).png'),
#  PosixPath('archive/shapes/triangles/drawing(40).png'),
#  PosixPath('archive/shapes/triangles/drawing(97).png'),
#  PosixPath('archive/shapes/triangles/drawing(63).png'),
#  PosixPath('archive/shapes/triangles/drawing(42).png'),
#  PosixPath('archive/shapes/triangles/drawing(69).png'),
#  PosixPath('archive/shapes/triangles/drawing(88).png'),
#  PosixPath('archive/shapes/triangles/drawing(49).png'),
#  PosixPath('archive/shapes/triangles/drawing(31).png'),
#  PosixPath('archive/shapes/triangles/drawing(80).png'),
#  PosixPath('archive/shapes/triangles/drawing(28).png'),
#  PosixPath('archive/shapes/triangles/drawing(68).png'),
#  PosixPath('archive/shapes/triangles/drawing(67).png'),
#  PosixPath('archive/shapes/triangles/drawing(66).png'),
#  PosixPath('archive/shapes/triangles/drawing(72).png'),
#  PosixPath('archive/shapes/triangles/drawing(93).png'),
#  PosixPath('archive/shapes/triangles/drawing(54).png'),
#  PosixPath('archive/shapes/triangles/drawing(15).png'),
#  PosixPath('archive/shapes/triangles/drawing(74).png'),
#  PosixPath('archive/shapes/triangles/drawing(38).png'),
#  PosixPath('archive/shapes/triangles/drawing(99).png'),
#  PosixPath('archive/shapes/triangles/drawing(30).png'),
#  PosixPath('archive/shapes/triangles/drawing(13).png'),
#  PosixPath('archive/shapes/triangles/drawing(4).png'),
#  PosixPath('archive/shapes/triangles/drawing(12).png'),
#  PosixPath('archive/shapes/triangles/drawing(18).png'),
#  PosixPath('archive/shapes/triangles/drawing(7).png'),
#  PosixPath('archive/shapes/triangles/drawing(16).png'),
#  PosixPath('archive/shapes/triangles/drawing(17).png'),
#  PosixPath('archive/shapes/triangles/drawing(55).png'),
#  PosixPath('archive/shapes/triangles/drawing(84).png'),
#  PosixPath('archive/shapes/triangles/drawing(70).png'),
#  PosixPath('archive/shapes/triangles/drawing(53).png'),
#  PosixPath('archive/shapes/triangles/drawing(20).png'),
#  PosixPath('archive/shapes/triangles/drawing(73).png'),
#  PosixPath('archive/shapes/triangles/drawing(23).png'),
#  PosixPath('archive/shapes/triangles/drawing(37).png'),
#  PosixPath('archive/shapes/triangles/drawing(43).png'),
#  PosixPath('archive/shapes/triangles/drawing(6).png'),
#  PosixPath('archive/shapes/triangles/drawing(8).png'),
#  PosixPath('archive/shapes/triangles/drawing(82).png'),
#  PosixPath('archive/shapes/triangles/drawing(46).png'),
#  PosixPath('archive/shapes/triangles/drawing(44).png'),
#  PosixPath('archive/shapes/circles/drawing(47).png'),
#  PosixPath('archive/shapes/circles/drawing(3).png'),
#  PosixPath('archive/shapes/circles/drawing(36).png'),
#  PosixPath('archive/shapes/circles/drawing(100).png'),
#  PosixPath('archive/shapes/circles/drawing(98).png'),
#  PosixPath('archive/shapes/circles/drawing(65).png'),
#  PosixPath('archive/shapes/circles/drawing(90).png'),
#  PosixPath('archive/shapes/circles/drawing(19).png'),
#  PosixPath('archive/shapes/circles/drawing(9).png'),
#  PosixPath('archive/shapes/circles/drawing(92).png'),
#  PosixPath('archive/shapes/circles/drawing(5).png'),
#  PosixPath('archive/shapes/circles/drawing(50).png'),
#  PosixPath('archive/shapes/circles/drawing(86).png'),
#  PosixPath('archive/shapes/circles/drawing(83).png'),
#  PosixPath('archive/shapes/circles/drawing(95).png'),
#  PosixPath('archive/shapes/circles/drawing(87).png'),
#  PosixPath('archive/shapes/circles/drawing(35).png'),
#  PosixPath('archive/shapes/circles/drawing(11).png'),
#  PosixPath('archive/shapes/circles/drawing(89).png'),
#  PosixPath('archive/shapes/circles/drawing(41).png'),
#  PosixPath('archive/shapes/circles/drawing(79).png'),
#  PosixPath('archive/shapes/circles/drawing(78).png'),
#  PosixPath('archive/shapes/circles/drawing(81).png'),
#  PosixPath('archive/shapes/circles/drawing(85).png'),
#  PosixPath('archive/shapes/circles/drawing(21).png'),
#  PosixPath('archive/shapes/circles/drawing(22).png'),
#  PosixPath('archive/shapes/circles/drawing(45).png'),
#  PosixPath('archive/shapes/circles/drawing(48).png'),
#  PosixPath('archive/shapes/circles/drawing(26).png'),
#  PosixPath('archive/shapes/circles/drawing(64).png'),
#  PosixPath('archive/shapes/circles/drawing(96).png'),
#  PosixPath('archive/shapes/circles/drawing(76).png'),
#  PosixPath('archive/shapes/circles/drawing(2).png'),
#  PosixPath('archive/shapes/circles/drawing(60).png'),
#  PosixPath('archive/shapes/circles/drawing(71).png'),
#  PosixPath('archive/shapes/circles/drawing(39).png'),
#  PosixPath('archive/shapes/circles/drawing(34).png'),
#  PosixPath('archive/shapes/circles/drawing(33).png'),
#  PosixPath('archive/shapes/circles/drawing(10).png'),
#  PosixPath('archive/shapes/circles/drawing(25).png'),
#  PosixPath('archive/shapes/circles/drawing(91).png'),
#  PosixPath('archive/shapes/circles/drawing(57).png'),
#  PosixPath('archive/shapes/circles/drawing(27).png'),
#  PosixPath('archive/shapes/circles/drawing(52).png'),
#  PosixPath('archive/shapes/circles/drawing(51).png'),
#  PosixPath('archive/shapes/circles/drawing(59).png'),
#  PosixPath('archive/shapes/circles/drawing(14).png'),
#  PosixPath('archive/shapes/circles/drawing(56).png'),
#  PosixPath('archive/shapes/circles/drawing(77).png'),
#  PosixPath('archive/shapes/circles/drawing(29).png'),
#  PosixPath('archive/shapes/circles/drawing(75).png'),
#  PosixPath('archive/shapes/circles/drawing(62).png'),
#  PosixPath('archive/shapes/circles/drawing(94).png'),
#  PosixPath('archive/shapes/circles/drawing(1).png'),
#  PosixPath('archive/shapes/circles/drawing(24).png'),
#  PosixPath('archive/shapes/circles/drawing(58).png'),
#  PosixPath('archive/shapes/circles/drawing(61).png'),
#  PosixPath('archive/shapes/circles/drawing(32).png'),
#  PosixPath('archive/shapes/circles/drawing(40).png'),
#  PosixPath('archive/shapes/circles/drawing(97).png'),
#  PosixPath('archive/shapes/circles/drawing(63).png'),
#  PosixPath('archive/shapes/circles/drawing(42).png'),
#  PosixPath('archive/shapes/circles/drawing(69).png'),
#  PosixPath('archive/shapes/circles/drawing(88).png'),
#  PosixPath('archive/shapes/circles/drawing(49).png'),
#  PosixPath('archive/shapes/circles/drawing(31).png'),
#  PosixPath('archive/shapes/circles/drawing(80).png'),
#  PosixPath('archive/shapes/circles/drawing(28).png'),
#  PosixPath('archive/shapes/circles/drawing(68).png'),
#  PosixPath('archive/shapes/circles/drawing(67).png'),
#  PosixPath('archive/shapes/circles/drawing(66).png'),
#  PosixPath('archive/shapes/circles/drawing(72).png'),
#  PosixPath('archive/shapes/circles/drawing(93).png'),
#  PosixPath('archive/shapes/circles/drawing(54).png'),
#  PosixPath('archive/shapes/circles/drawing(15).png'),
#  PosixPath('archive/shapes/circles/drawing(74).png'),
#  PosixPath('archive/shapes/circles/drawing(38).png'),
#  PosixPath('archive/shapes/circles/drawing(99).png'),
#  PosixPath('archive/shapes/circles/drawing(30).png'),
#  PosixPath('archive/shapes/circles/drawing(13).png'),
#  PosixPath('archive/shapes/circles/drawing(4).png'),
#  PosixPath('archive/shapes/circles/drawing(12).png'),
#  PosixPath('archive/shapes/circles/drawing(18).png'),
#  PosixPath('archive/shapes/circles/drawing(7).png'),
#  PosixPath('archive/shapes/circles/drawing(16).png'),
#  PosixPath('archive/shapes/circles/drawing(17).png'),
#  PosixPath('archive/shapes/circles/drawing(55).png'),
#  PosixPath('archive/shapes/circles/drawing(84).png'),
#  PosixPath('archive/shapes/circles/drawing(70).png'),
#  PosixPath('archive/shapes/circles/drawing(53).png'),
#  PosixPath('archive/shapes/circles/drawing(20).png'),
#  PosixPath('archive/shapes/circles/drawing(73).png'),
#  PosixPath('archive/shapes/circles/drawing(23).png'),
#  PosixPath('archive/shapes/circles/drawing(37).png'),
#  PosixPath('archive/shapes/circles/drawing(43).png'),
#  PosixPath('archive/shapes/circles/drawing(6).png'),
#  PosixPath('archive/shapes/circles/drawing(8).png'),
#  PosixPath('archive/shapes/circles/drawing(82).png'),
#  PosixPath('archive/shapes/circles/drawing(46).png'),
#  PosixPath('archive/shapes/circles/drawing(44).png'),
#  PosixPath('archive/shapes/squares/drawing(47).png'),
#  PosixPath('archive/shapes/squares/drawing(3).png'),
#  PosixPath('archive/shapes/squares/drawing(36).png'),
#  PosixPath('archive/shapes/squares/drawing(100).png'),
#  PosixPath('archive/shapes/squares/drawing(98).png'),
#  PosixPath('archive/shapes/squares/drawing(65).png'),
#  PosixPath('archive/shapes/squares/drawing(90).png'),
#  PosixPath('archive/shapes/squares/drawing(19).png'),
#  PosixPath('archive/shapes/squares/drawing(9).png'),
#  PosixPath('archive/shapes/squares/drawing(92).png'),
#  PosixPath('archive/shapes/squares/drawing(5).png'),
#  PosixPath('archive/shapes/squares/drawing(50).png'),
#  PosixPath('archive/shapes/squares/drawing(86).png'),
#  PosixPath('archive/shapes/squares/drawing(83).png'),
#  PosixPath('archive/shapes/squares/drawing(95).png'),
#  PosixPath('archive/shapes/squares/drawing(87).png'),
#  PosixPath('archive/shapes/squares/drawing(35).png'),
#  PosixPath('archive/shapes/squares/drawing(11).png'),
#  PosixPath('archive/shapes/squares/drawing(89).png'),
#  PosixPath('archive/shapes/squares/drawing(41).png'),
#  PosixPath('archive/shapes/squares/drawing(79).png'),
#  PosixPath('archive/shapes/squares/drawing(78).png'),
#  PosixPath('archive/shapes/squares/drawing(81).png'),
#  PosixPath('archive/shapes/squares/drawing(85).png'),
#  PosixPath('archive/shapes/squares/drawing(21).png'),
#  PosixPath('archive/shapes/squares/drawing(22).png'),
#  PosixPath('archive/shapes/squares/drawing(45).png'),
#  PosixPath('archive/shapes/squares/drawing(48).png'),
#  PosixPath('archive/shapes/squares/drawing(26).png'),
#  PosixPath('archive/shapes/squares/drawing(64).png'),
#  PosixPath('archive/shapes/squares/drawing(96).png'),
#  PosixPath('archive/shapes/squares/drawing(76).png'),
#  PosixPath('archive/shapes/squares/drawing(2).png'),
#  PosixPath('archive/shapes/squares/drawing(60).png'),
#  PosixPath('archive/shapes/squares/drawing(71).png'),
#  PosixPath('archive/shapes/squares/drawing(39).png'),
#  PosixPath('archive/shapes/squares/drawing(34).png'),
#  PosixPath('archive/shapes/squares/drawing(33).png'),
#  PosixPath('archive/shapes/squares/drawing(10).png'),
#  PosixPath('archive/shapes/squares/drawing(25).png'),
#  PosixPath('archive/shapes/squares/drawing(91).png'),
#  PosixPath('archive/shapes/squares/drawing(57).png'),
#  PosixPath('archive/shapes/squares/drawing(27).png'),
#  PosixPath('archive/shapes/squares/drawing(52).png'),
#  PosixPath('archive/shapes/squares/drawing(51).png'),
#  PosixPath('archive/shapes/squares/drawing(59).png'),
#  PosixPath('archive/shapes/squares/drawing(14).png'),
#  PosixPath('archive/shapes/squares/drawing(56).png'),
#  PosixPath('archive/shapes/squares/drawing(77).png'),
#  PosixPath('archive/shapes/squares/drawing(29).png'),
#  PosixPath('archive/shapes/squares/drawing(75).png'),
#  PosixPath('archive/shapes/squares/drawing(62).png'),
#  PosixPath('archive/shapes/squares/drawing(94).png'),
#  PosixPath('archive/shapes/squares/drawing(1).png'),
#  PosixPath('archive/shapes/squares/drawing(24).png'),
#  PosixPath('archive/shapes/squares/drawing(58).png'),
#  PosixPath('archive/shapes/squares/drawing(61).png'),
#  PosixPath('archive/shapes/squares/drawing(32).png'),
#  PosixPath('archive/shapes/squares/drawing(40).png'),
#  PosixPath('archive/shapes/squares/drawing(97).png'),
#  PosixPath('archive/shapes/squares/drawing(63).png'),
#  PosixPath('archive/shapes/squares/drawing(42).png'),
#  PosixPath('archive/shapes/squares/drawing(69).png'),
#  PosixPath('archive/shapes/squares/drawing(88).png'),
#  PosixPath('archive/shapes/squares/drawing(49).png'),
#  PosixPath('archive/shapes/squares/drawing(31).png'),
#  PosixPath('archive/shapes/squares/drawing(80).png'),
#  PosixPath('archive/shapes/squares/drawing(28).png'),
#  PosixPath('archive/shapes/squares/drawing(68).png'),
#  PosixPath('archive/shapes/squares/drawing(67).png'),
#  PosixPath('archive/shapes/squares/drawing(66).png'),
#  PosixPath('archive/shapes/squares/drawing(72).png'),
#  PosixPath('archive/shapes/squares/drawing(93).png'),
#  PosixPath('archive/shapes/squares/drawing(54).png'),
#  PosixPath('archive/shapes/squares/drawing(15).png'),
#  PosixPath('archive/shapes/squares/drawing(74).png'),
#  PosixPath('archive/shapes/squares/drawing(38).png'),
#  PosixPath('archive/shapes/squares/drawing(99).png'),
#  PosixPath('archive/shapes/squares/drawing(30).png'),
#  PosixPath('archive/shapes/squares/drawing(13).png'),
#  PosixPath('archive/shapes/squares/drawing(4).png'),
#  PosixPath('archive/shapes/squares/drawing(12).png'),
#  PosixPath('archive/shapes/squares/drawing(18).png'),
#  PosixPath('archive/shapes/squares/drawing(7).png'),
#  PosixPath('archive/shapes/squares/drawing(16).png'),
#  PosixPath('archive/shapes/squares/drawing(17).png'),
#  PosixPath('archive/shapes/squares/drawing(55).png'),
#  PosixPath('archive/shapes/squares/drawing(84).png'),
#  PosixPath('archive/shapes/squares/drawing(70).png'),
#  PosixPath('archive/shapes/squares/drawing(53).png'),
#  PosixPath('archive/shapes/squares/drawing(20).png'),
#  PosixPath('archive/shapes/squares/drawing(73).png'),
#  PosixPath('archive/shapes/squares/drawing(23).png'),
#  PosixPath('archive/shapes/squares/drawing(37).png'),
#  PosixPath('archive/shapes/squares/drawing(43).png'),
#  PosixPath('archive/shapes/squares/drawing(6).png'),
#  PosixPath('archive/shapes/squares/drawing(8).png'),
#  PosixPath('archive/shapes/squares/drawing(82).png'),
#  PosixPath('archive/shapes/squares/drawing(46).png'),
#  PosixPath('archive/shapes/squares/drawing(44).png')]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares']

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

image_df = pd.concat([filepaths, labels], axis=1)
image_df
# Out:
#                                       Filepath      Label
# 0     archive/shapes/triangles/drawing(47).png  triangles
# 1      archive/shapes/triangles/drawing(3).png  triangles
# 2     archive/shapes/triangles/drawing(36).png  triangles
# 3    archive/shapes/triangles/drawing(100).png  triangles
# 4     archive/shapes/triangles/drawing(98).png  triangles
# ..                                         ...        ...
# 295      archive/shapes/squares/drawing(6).png    squares
# 296      archive/shapes/squares/drawing(8).png    squares
# 297     archive/shapes/squares/drawing(82).png    squares
# 298     archive/shapes/squares/drawing(46).png    squares
# 299     archive/shapes/squares/drawing(44).png    squares
#
# [300 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.7, shuffle=True, random_state=1)

# %%
train_df
# Out:
#                                      Filepath      Label
# 253     archive/shapes/squares/drawing(1).png    squares
# 19   archive/shapes/triangles/drawing(41).png  triangles
# 14   archive/shapes/triangles/drawing(95).png  triangles
# 91   archive/shapes/triangles/drawing(73).png  triangles
# 296     archive/shapes/squares/drawing(8).png    squares
# ..                                        ...        ...
# 203   archive/shapes/squares/drawing(100).png    squares
# 255    archive/shapes/squares/drawing(58).png    squares
# 72   archive/shapes/triangles/drawing(93).png  triangles
# 235    archive/shapes/squares/drawing(39).png    squares
# 37   archive/shapes/triangles/drawing(33).png  triangles
#
# [210 rows x 2 columns]

# %%
test_df
# Out:
#                                    Filepath    Label
# 189  archive/shapes/circles/drawing(53).png  circles
# 123  archive/shapes/circles/drawing(85).png  circles
# 185  archive/shapes/circles/drawing(17).png  circles
# 213  archive/shapes/squares/drawing(83).png  squares
# 106  archive/shapes/circles/drawing(90).png  circles
# ..                                      ...      ...
# 181  archive/shapes/circles/drawing(12).png  circles
# 290  archive/shapes/squares/drawing(20).png  squares
# 244  archive/shapes/squares/drawing(51).png  squares
# 197  archive/shapes/circles/drawing(82).png  circles
# 279  archive/shapes/squares/drawing(13).png  squares
#
# [90 rows x 2 columns]

# %% [markdown]
# ### Loading Image Data

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe = train_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = True,
    seed = 42,
    subset = 'training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe = train_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = True,
    seed = 42,
    subset = 'validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe = test_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle = False
)
# Out:
# Found 168 validated image filenames belonging to 3 classes.
# Found 42 validated image filenames belonging to 3 classes.
# Found 90 validated image filenames belonging to 3 classes.

# %% [markdown]
# ### Training

# %%
inputs = tf.keras.Input(shape=(28, 28, 1))
x = tf.keras.layers.Conv2D(filters=6, kernel_size=(3,3), activation='relu')(inputs)
x = tf.keras.layers.MaxPooling2D()(x)
x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

history = model.fit(
    train_images,
    validation_data = val_images,
    epochs = 100,
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            filepath = './model.weights.h5',
            save_best_only=True,
            save_weights_only=True
        )
    ]
)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.3274 - loss: 1.0989 - val_accuracy: 0.2619 - val_loss: 1.0981
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.