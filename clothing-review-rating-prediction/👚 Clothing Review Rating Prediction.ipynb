# %% [markdown]
# ## Clothing Review Rating Prediction
#
# Given *reviews of women's clothing*, let's try to predict whether the rating associated with the review will be **5-star** or not.
#
# We will use a TensorFlow recurrent neural network to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import tensorflow as tf

# %%
data = pd.read_csv('archive/Womens Clothing E-Commerce Reviews.csv')
data
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 2                    0                        0         General
# 3                    1                        0  General Petite
# 4                    1                        6         General
# ...                ...                      ...             ...
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# 23485                1                       22  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses
#
# [23486 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Preprocessing

# %%
df = data.copy()

# %%
# Drop rows with missing reviews
missing_review_rows = df[df['Review Text'].isna()].index
df = df.drop(missing_review_rows, axis=0).reset_index(drop=True)

# %%
# Use only the reviews and rating columns
y = df['Rating'].copy()
X = df['Review Text'].copy()

# %%
y.isna().sum()
# Out:
# np.int64(0)

# %%
X.isna().sum()
# Out:
# np.int64(0)

# %%
y
# Out:
# 0        4
# 1        5
# 2        3
# 3        5
# 4        5
#         ..
# 22636    5
# 22637    3
# 22638    3
# 22639    3
# 22640    5
# Name: Rating, Length: 22641, dtype: int64

# %%
# Make y a binary target
y = y.apply(lambda x: 1 if x == 5 else 0)

# %%
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 22636    1
# 22637    0
# 22638    0
# 22639    0
# 22640    1
# Name: Rating, Length: 22641, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1])

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)

# %%
X_train
# Out:
# 9232     This dress is adorable. it simply did not fi o...
# 13974    The fit was not flattering at all, but the wor...
# 17979    I bought this top in both colors. the fit is p...
# 9586     This is even cuter in person than it is in the...
# 9358     I couldn't believe there weren't more reviews ...
#                                ...
# 10955    Pretty color, but i was hoping for a thicker, ...
# 17289    This sweater coat is a keeper. yes it runs lar...
# 5192     Should have ordered the xl instead of the larg...
# 12172    I really like this denim jacket with the plaid...
# 235      Love pilcro, love the stripes and the length -...
# Name: Review Text, Length: 15848, dtype: object

# %%
X_train.shape, X_test.shape
# Out:
# ((15848,), (6793,))

# %%
# Learn the vocabulary
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# Find the size of the vocabulary
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'and': 3,
#  'a': 4,
#  'it': 5,
#  'is': 6,
#  'this': 7,
#  'to': 8,
#  'in': 9,
#  'but': 10,
#  'on': 11,
#  'for': 12,
#  'of': 13,
#  'with': 14,
#  'was': 15,
#  'so': 16,
#  'my': 17,
#  'dress': 18,
#  'not': 19,
#  'that': 20,
#  'size': 21,
#  'love': 22,
#  'have': 23,
#  'very': 24,
#  'are': 25,
#  'fit': 26,
#  'top': 27,
#  'like': 28,
#  'be': 29,
#  'me': 30,
#  'as': 31,
#  'wear': 32,
#  "it's": 33,
#  'too': 34,
#  'great': 35,
#  "i'm": 36,
#  'am': 37,
#  'or': 38,
#  'just': 39,
#  'you': 40,
#  'they': 41,
#  'would': 42,
#  'at': 43,
#  'up': 44,
#  'fabric': 45,
#  'small': 46,
#  'color': 47,
#  'look': 48,
#  'if': 49,
#  'really': 50,
#  'more': 51,
#  'ordered': 52,
#  'perfect': 53,
#  'little': 54,
#  'these': 55,
#  'will': 56,
#  'one': 57,
#  'flattering': 58,
#  'well': 59,
#  'an': 60,
#  'soft': 61,
#  'out': 62,
#  'back': 63,
#  'because': 64,
#  'can': 65,
#  'had': 66,
#  '\r': 67,
#  'cute': 68,
#  'comfortable': 69,
#  'nice': 70,
#  'than': 71,
#  'beautiful': 72,
#  'when': 73,
#  'bought': 74,
#  'all': 75,
#  'bit': 76,
#  'which': 77,
#  'looks': 78,
#  'shirt': 79,
#  'down': 80,
#  'large': 81,
#  'fits': 82,
#  'material': 83,
#  'much': 84,
#  'them': 85,
#  'length': 86,
#  'also': 87,
#  'has': 88,
#  'sweater': 89,
#  'long': 90,
#  'jeans': 91,
#  'got': 92,
#  'colors': 93,
#  'petite': 94,
#  'waist': 95,
#  'quality': 96,
#  'medium': 97,
#  'think': 98,
#  'xs': 99,
#  'even': 100,
#  'pretty': 101,
#  'work': 102,
#  'tried': 103,
#  'retailer': 104,
#  'usually': 105,
#  'from': 106,
#  'store': 107,
#  'good': 108,
#  'way': 109,
#  'skirt': 110,
#  'about': 111,
#  'other': 112,
#  'pants': 113,
#  'made': 114,
#  'only': 115,
#  'cut': 116,
#  'short': 117,
#  'big': 118,
#  'get': 119,
#  'could': 120,
#  'were': 121,
#  "don't": 122,
#  'see': 123,
#  'black': 124,
#  "didn't": 125,
#  'still': 126,
#  'right': 127,
#  'there': 128,
#  'true': 129,
#  'super': 130,
#  'did': 131,
#  'runs': 132,
#  'style': 133,
#  'no': 134,
#  'do': 135,
#  'online': 136,
#  'sleeves': 137,
#  'wearing': 138,
#  'white': 139,
#  'summer': 140,
#  'purchased': 141,
#  'however': 142,
#  'design': 143,
#  'does': 144,
#  'go': 145,
#  'tight': 146,
#  'off': 147,
#  'perfectly': 148,
#  'enough': 149,
#  'over': 150,
#  'looked': 151,
#  'feel': 152,
#  'some': 153,
#  'model': 154,
#  '2': 155,
#  'definitely': 156,
#  'though': 157,
#  'loved': 158,
#  'blue': 159,
#  '4': 160,
#  'sale': 161,
#  'front': 162,
#  'been': 163,
#  'person': 164,
#  'lbs': 165,
#  'what': 166,
#  'price': 167,
#  'how': 168,
#  'better': 169,
#  'body': 170,
#  'jacket': 171,
#  'try': 172,
#  'loose': 173,
#  'fall': 174,
#  'first': 175,
#  'bottom': 176,
#  'your': 177,
#  'around': 178,
#  'going': 179,
#  'worn': 180,
#  '6': 181,
#  'looking': 182,
#  'high': 183,
#  'light': 184,
#  'both': 185,
#  'regular': 186,
#  'chest': 187,
#  'wanted': 188,
#  'time': 189,
#  'thought': 190,
#  'arms': 191,
#  'lovely': 192,
#  'shape': 193,
#  'many': 194,
#  'piece': 195,
#  'gorgeous': 196,
#  'thin': 197,
#  'make': 198,
#  'shoulders': 199,
#  'through': 200,
#  'saw': 201,
#  's': 202,
#  'casual': 203,
#  'after': 204,
#  'compliments': 205,
#  'bust': 206,
#  'pair': 207,
#  'makes': 208,
#  'want': 209,
#  'without': 210,
#  'side': 211,
#  'recommend': 212,
#  'tops': 213,
#  'pattern': 214,
#  "doesn't": 215,
#  'need': 216,
#  'went': 217,
#  'bra': 218,
#  'run': 219,
#  'weight': 220,
#  'found': 221,
#  'blouse': 222,
#  'being': 223,
#  'buy': 224,
#  'reviews': 225,
#  "can't": 226,
#  'hips': 227,
#  'print': 228,
#  'picture': 229,
#  'wore': 230,
#  "i've": 231,
#  'sure': 232,
#  '8': 233,
#  'find': 234,
#  'wish': 235,
#  'different': 236,
#  'lot': 237,
#  'order': 238,
#  'dresses': 239,
#  'since': 240,
#  'by': 241,
#  'usual': 242,
#  'received': 243,
#  'm': 244,
#  'longer': 245,
#  'comfy': 246,
#  'quite': 247,
#  'normally': 248,
#  'its': 249,
#  '5': 250,
#  'while': 251,
#  'any': 252,
#  'fitted': 253,
#  'most': 254,
#  'overall': 255,
#  'return': 256,
#  'slightly': 257,
#  'may': 258,
#  'might': 259,
#  'detail': 260,
#  'absolutely': 261,
#  'nicely': 262,
#  'then': 263,
#  'day': 264,
#  'keep': 265,
#  'two': 266,
#  'felt': 267,
#  'another': 268,
#  'stretch': 269,
#  'neck': 270,
#  'say': 271,
#  'leggings': 272,
#  'green': 273,
#  'wide': 274,
#  'under': 275,
#  'now': 276,
#  'red': 277,
#  'lace': 278,
#  'boxy': 279,
#  '10': 280,
#  'unique': 281,
#  'underneath': 282,
#  'easy': 283,
#  'almost': 284,
#  'fun': 285,
#  "wasn't": 286,
#  'extra': 287,
#  'probably': 288,
#  'sizes': 289,
#  'tank': 290,
#  'warm': 291,
#  'low': 292,
#  'something': 293,
#  'photo': 294,
#  'smaller': 295,
#  'sheer': 296,
#  'happy': 297,
#  'unfortunately': 298,
#  "5'4": 299,
#  'sizing': 300,
#  'actually': 301,
#  'area': 302,
#  'such': 303,
#  'shorter': 304,
#  'purchase': 305,
#  'pockets': 306,
#  'worth': 307,
#  'into': 308,
#  'same': 309,
#  'fine': 310,
#  'flowy': 311,
#  'tee': 312,
#  'feels': 313,
#  'dressed': 314,
#  'every': 315,
#  'between': 316,
#  'full': 317,
#  'put': 318,
#  'sized': 319,
#  't': 320,
#  'everything': 321,
#  'tall': 322,
#  'maybe': 323,
#  'always': 324,
#  'said': 325,
#  'line': 326,
#  'boots': 327,
#  'glad': 328,
#  'yet': 329,
#  'denim': 330,
#  'buttons': 331,
#  'skinny': 332,
#  'reference': 333,
#  'wait': 334,
#  'adorable': 335,
#  'spring': 336,
#  'give': 337,
#  'larger': 338,
#  'versatile': 339,
#  'disappointed': 340,
#  'where': 341,
#  'tts': 342,
#  'liked': 343,
#  'thick': 344,
#  'navy': 345,
#  'decided': 346,
#  'part': 347,
#  'figure': 348,
#  'should': 349,
#  'neckline': 350,
#  'favorite': 351,
#  'grey': 352,
#  'above': 353,
#  'winter': 354,
#  'wash': 355,
#  'huge': 356,
#  'heavy': 357,
#  'returned': 358,
#  'easily': 359,
#  'amazing': 360,
#  "i'd": 361,
#  'came': 362,
#  'coat': 363,
#  'shorts': 364,
#  'pink': 365,
#  'problem': 366,
#  'best': 367,
#  'snug': 368,
#  'fitting': 369,
#  'button': 370,
#  'thing': 371,
#  'especially': 372,
#  'seems': 373,
#  'details': 374,
#  "couldn't": 375,
#  'room': 376,
#  'slip': 377,
#  'hem': 378,
#  'normal': 379,
#  "5'3": 380,
#  'take': 381,
#  'lightweight': 382,
#  'few': 383,
#  '3': 384,
#  'cotton': 385,
#  "isn't": 386,
#  'l': 387,
#  'know': 388,
#  'feminine': 389,
#  'tunic': 390,
#  'cami': 391,
#  'kind': 392,
#  'embroidery': 393,
#  'knit': 394,
#  'pictured': 395,
#  'reviewers': 396,
#  'lined': 397,
#  'hit': 398,
#  "that's": 399,
#  'curvy': 400,
#  'arm': 401,
#  'knee': 402,
#  'expected': 403,
#  'returning': 404,
#  "5'5": 405,
#  'belt': 406,
#  'dark': 407,
#  'although': 408,
#  'torso': 409,
#  'took': 410,
#  '12': 411,
#  'before': 412,
#  'show': 413,
#  'xl': 414,
#  'beautifully': 415,
#  'cardigan': 416,
#  '0': 417,
#  "5'2": 418,
#  'typically': 419,
#  'never': 420,
#  'frame': 421,
#  'goes': 422,
#  'reviewer': 423,
#  'able': 424,
#  'anything': 425,
#  'today': 426,
#  "i'll": 427,
#  'washed': 428,
#  'lining': 429,
#  'sleeve': 430,
#  'legs': 431,
#  'works': 432,
#  'hits': 433,
#  'year': 434,
#  'once': 435,
#  'excited': 436,
#  'either': 437,
#  'extremely': 438,
#  'xxs': 439,
#  'those': 440,
#  'bad': 441,
#  'shown': 442,
#  "5'7": 443,
#  'who': 444,
#  'ended': 445,
#  'highly': 446,
#  'cool': 447,
#  'sold': 448,
#  'someone': 449,
#  'why': 450,
#  'photos': 451,
#  'type': 452,
#  'trying': 453,
#  'below': 454,
#  'stretchy': 455,
#  'already': 456,
#  'issue': 457,
#  'holes': 458,
#  'things': 459,
#  'new': 460,
#  'tie': 461,
#  'last': 462,
#  'needed': 463,
#  'days': 464,
#  'weather': 465,
#  "5'6": 466,
#  "you're": 467,
#  'shoulder': 468,
#  'come': 469,
#  'brand': 470,
#  'otherwise': 471,
#  'hoping': 472,
#  "5'": 473,
#  'gray': 474,
#  'orange': 475,
#  'fell': 476,
#  'inches': 477,
#  'across': 478,
#  '26': 479,
#  'zipper': 480,
#  '1': 481,
#  'keeping': 482,
#  'hard': 483,
#  'sadly': 484,
#  'heels': 485,
#  'layer': 486,
#  'straps': 487,
#  'arrived': 488,
#  'several': 489,
#  'wardrobe': 490,
#  'agree': 491,
#  'least': 492,
#  'vest': 493,
#  'due': 494,
#  'add': 495,
#  'again': 496,
#  'ever': 497,
#  "wouldn't": 498,
#  'getting': 499,
#  "5'8": 500,
#  'cheap': 501,
#  'cozy': 502,
#  'away': 503,
#  'suit': 504,
#  'sides': 505,
#  'local': 506,
#  'swing': 507,
#  'rather': 508,
#  'must': 509,
#  'skin': 510,
#  'pounds': 511,
#  'pictures': 512,
#  'exactly': 513,
#  'dry': 514,
#  'pilcro': 515,
#  'stylish': 516,
#  'hot': 517,
#  'nothing': 518,
#  'vibrant': 519,
#  "they're": 520,
#  'ran': 521,
#  'baggy': 522,
#  'others': 523,
#  'unflattering': 524,
#  'slim': 525,
#  'tad': 526,
#  'based': 527,
#  'bright': 528,
#  'plan': 529,
#  'classic': 530,
#  'surprised': 531,
#  'touch': 532,
#  'wonderful': 533,
#  'years': 534,
#  'ordering': 535,
#  'item': 536,
#  'open': 537,
#  'shirts': 538,
#  'less': 539,
#  'roomy': 540,
#  'straight': 541,
#  'seem': 542,
#  'paired': 543,
#  'ankle': 544,
#  'delicate': 545,
#  'available': 546,
#  'use': 547,
#  'drape': 548,
#  'stunning': 549,
#  'simple': 550,
#  'hangs': 551,
#  'tights': 552,
#  'times': 553,
#  'yellow': 554,
#  'plus': 555,
#  'pull': 556,
#  'cropped': 557,
#  'kept': 558,
#  'waisted': 559,
#  'bigger': 560,
#  'drapes': 561,
#  'instead': 562,
#  'night': 563,
#  'here': 564,
#  'gives': 565,
#  'their': 566,
#  'review': 567,
#  'skirts': 568,
#  'busty': 569,
#  'athletic': 570,
#  'sometimes': 571,
#  'having': 572,
#  '28': 573,
#  'seemed': 574,
#  'buying': 575,
#  'cover': 576,
#  'tiny': 577,
#  'version': 578,
#  'itchy': 579,
#  'adds': 580,
#  'lots': 581,
#  'own': 582,
#  'v': 583,
#  "5'9": 584,
#  'wedding': 585,
#  'collar': 586,
#  'she': 587,
#  'worked': 588,
#  'flat': 589,
#  'mine': 590,
#  'oversized': 591,
#  'end': 592,
#  '27': 593,
#  'shows': 594,
#  'far': 595,
#  'making': 596,
#  'weird': 597,
#  'booties': 598,
#  'elastic': 599,
#  'completely': 600,
#  'immediately': 601,
#  'comes': 602,
#  'myself': 603,
#  'texture': 604,
#  'mid': 605,
#  "5'1": 606,
#  'higher': 607,
#  'mentioned': 608,
#  'cream': 609,
#  '115': 610,
#  'lower': 611,
#  'jumpsuit': 612,
#  'special': 613,
#  'totally': 614,
#  'thinking': 615,
#  'wool': 616,
#  'form': 617,
#  "won't": 618,
#  'linen': 619,
#  'season': 620,
#  'flare': 621,
#  'hourglass': 622,
#  'knees': 623,
#  'staple': 624,
#  'falls': 625,
#  'jean': 626,
#  '120': 627,
#  'previous': 628,
#  'clothes': 629,
#  'ivory': 630,
#  'neutral': 631,
#  'second': 632,
#  'broad': 633,
#  'sandals': 634,
#  'else': 635,
#  'leg': 636,
#  "there's": 637,
#  'stiff': 638,
#  'eye': 639,
#  'often': 640,
#  'awesome': 641,
#  'curves': 642,
#  'months': 643,
#  'layering': 644,
#  'cold': 645,
#  'finally': 646,
#  'sweaters': 647,
#  'interesting': 648,
#  'rise': 649,
#  'substantial': 650,
#  'fact': 651,
#  'incredibly': 652,
#  'knew': 653,
#  'people': 654,
#  'used': 655,
#  'flats': 656,
#  'throw': 657,
#  'bulky': 658,
#  'sexy': 659,
#  'slimming': 660,
#  'upper': 661,
#  'amount': 662,
#  'brown': 663,
#  'half': 664,
#  'flow': 665,
#  'depending': 666,
#  'ok': 667,
#  'worried': 668,
#  'mind': 669,
#  'wrong': 670,
#  'read': 671,
#  'armholes': 672,
#  'basic': 673,
#  'addition': 674,
#  'rich': 675,
#  'mail': 676,
#  '30': 677,
#  'odd': 678,
#  'b': 679,
#  'maternity': 680,
#  'hope': 681,
#  'gave': 682,
#  'elegant': 683,
#  'inside': 684,
#  '135': 685,
#  'hip': 686,
#  'justice': 687,
#  'closet': 688,
#  'home': 689,
#  'except': 690,
#  'exchange': 691,
#  'dressy': 692,
#  'build': 693,
#  'outfit': 694,
#  'appropriate': 695,
#  'point': 696,
#  'detailing': 697,
#  'deep': 698,
#  'perhaps': 699,
#  'appears': 700,
#  'clothing': 701,
#  'close': 702,
#  '25': 703,
#  'c': 704,
#  'reason': 705,
#  'tell': 706,
#  'hand': 707,
#  'couple': 708,
#  'hang': 709,
#  'silk': 710,
#  'somewhat': 711,
#  'next': 712,
#  'stripes': 713,
#  'similar': 714,
#  'left': 715,
#  'truly': 716,
#  'until': 717,
#  'complaint': 718,
#  'expect': 719,
#  'nude': 720,
#  'her': 721,
#  'colored': 722,
#  'prefer': 723,
#  'cannot': 724,
#  'idea': 725,
#  'during': 726,
#  'maeve': 727,
#  "haven't": 728,
#  'bodice': 729,
#  'anyway': 730,
#  'peplum': 731,
#  'yes': 732,
#  'pant': 733,
#  'seam': 734,
#  'w': 735,
#  'case': 736,
#  '140': 737,
#  'gotten': 738,
#  'hung': 739,
#  'thicker': 740,
#  'looser': 741,
#  'washing': 742,
#  'soon': 743,
#  'bottoms': 744,
#  'baby': 745,
#  'sad': 746,
#  '34': 747,
#  'forward': 748,
#  'subtle': 749,
#  '125': 750,
#  'fairly': 751,
#  'expecting': 752,
#  'deal': 753,
#  'middle': 754,
#  'flows': 755,
#  'purple': 756,
#  'added': 757,
#  'darker': 758,
#  '130': 759,
#  'along': 760,
#  'fan': 761,
#  'tag': 762,
#  'thighs': 763,
#  'hold': 764,
#  'tent': 765,
#  '34c': 766,
#  'everywhere': 767,
#  'gone': 768,
#  'old': 769,
#  'noticed': 770,
#  'chic': 771,
#  'past': 772,
#  'floral': 773,
#  'pleased': 774,
#  'awkward': 775,
#  'pairs': 776,
#  '34b': 777,
#  'heavier': 778,
#  'together': 779,
#  'gold': 780,
#  'band': 781,
#  'product': 782,
#  'barely': 783,
#  'slight': 784,
#  'opinion': 785,
#  'three': 786,
#  'romper': 787,
#  'pieces': 788,
#  'we': 789,
#  'issues': 790,
#  'sort': 791,
#  'feeling': 792,
#  'sweatshirt': 793,
#  'live': 794,
#  'place': 795,
#  'imagine': 796,
#  'unless': 797,
#  'please': 798,
#  'zip': 799,
#  'typical': 800,
#  'spot': 801,
#  'whole': 802,
#  'blazer': 803,
#  'office': 804,
#  'needs': 805,
#  'classy': 806,
#  'motif': 807,
#  'real': 808,
#  'butt': 809,
#  'seen': 810,
#  'fabulous': 811,
#  'believe': 812,
#  'pulled': 813,
#  'places': 814,
#  'taller': 815,
#  'seams': 816,
#  'waistband': 817,
#  'each': 818,
#  'strange': 819,
#  'inch': 820,
#  'girl': 821,
#  '34d': 822,
#  'fantastic': 823,
#  '14': 824,
#  'showing': 825,
#  'excellent': 826,
#  'sewn': 827,
#  '29': 828,
#  'tummy': 829,
#  'leather': 830,
#  'husband': 831,
#  'running': 832,
#  'chested': 833,
#  'reading': 834,
#  'says': 835,
#  'items': 836,
#  'forgiving': 837,
#  'stitching': 838,
#  'anyone': 839,
#  'lay': 840,
#  'generally': 841,
#  'lighter': 842,
#  'itself': 843,
#  'styling': 844,
#  'caught': 845,
#  'beach': 846,
#  "5'10": 847,
#  'party': 848,
#  'house': 849,
#  'clingy': 850,
#  'height': 851,
#  'narrow': 852,
#  'belly': 853,
#  'weekend': 854,
#  'rest': 855,
#  'slits': 856,
#  'done': 857,
#  'stay': 858,
#  'girls': 859,
#  'relaxed': 860,
#  'shaped': 861,
#  'chance': 862,
#  'care': 863,
#  'dinner': 864,
#  'tucked': 865,
#  '100': 866,
#  'necklace': 867,
#  'lines': 868,
#  'difficult': 869,
#  'tailored': 870,
#  'transition': 871,
#  'camisole': 872,
#  'seasons': 873,
#  'airy': 874,
#  'stars': 875,
#  'women': 876,
#  'sack': 877,
#  'd': 878,
#  'scratchy': 879,
#  'silhouette': 880,
#  'hide': 881,
#  'simply': 882,
#  "aren't": 883,
#  'ago': 884,
#  'help': 885,
#  'wow': 886,
#  'glove': 887,
#  'coverage': 888,
#  'option': 889,
#  'expensive': 890,
#  'comfort': 891,
#  'hanging': 892,
#  'p': 893,
#  'maxi': 894,
#  'plenty': 895,
#  'everyone': 896,
#  'wider': 897,
#  'swingy': 898,
#  'slender': 899,
#  'silky': 900,
#  'frumpy': 901,
#  'pear': 902,
#  'coral': 903,
#  'cooler': 904,
#  'pregnant': 905,
#  'meant': 906,
#  'clean': 907,
#  '40': 908,
#  'ag': 909,
#  'ladies': 910,
#  'despite': 911,
#  'jackets': 912,
#  'purchasing': 913,
#  'etc': 914,
#  'portion': 915,
#  'finding': 916,
#  'cup': 917,
#  'bag': 918,
#  'natural': 919,
#  'yesterday': 920,
#  'considering': 921,
#  'website': 922,
#  'pleats': 923,
#  '39': 924,
#  'poor': 925,
#  'stomach': 926,
#  'wrinkle': 927,
#  'prettier': 928,
#  'money': 929,
#  'layered': 930,
#  'pass': 931,
#  '38': 932,
#  'stock': 933,
#  'surprise': 934,
#  'consider': 935,
#  'uncomfortable': 936,
#  'thigh': 937,
#  'pricey': 938,
#  'keeper': 939,
#  'beige': 940,
#  'designed': 941,
#  'shade': 942,
#  'description': 943,
#  'polyester': 944,
#  'guess': 945,
#  'afraid': 946,
#  'send': 947,
#  '32': 948,
#  'beading': 949,
#  'disappointing': 950,
#  'plain': 951,
#  'hole': 952,
#  'solid': 953,
#  'life': 954,
#  'daughter': 955,
#  'note': 956,
#  'ruffle': 957,
#  'us': 958,
#  'week': 959,
#  '36': 960,
#  'plaid': 961,
#  'receive': 962,
#  'crazy': 963,
#  'patterns': 964,
#  'literally': 965,
#  'round': 966,
#  'poncho': 967,
#  'flowing': 968,
#  'average': 969,
#  'dressing': 970,
#  'shapeless': 971,
#  'stretched': 972,
#  'swimming': 973,
#  'tend': 974,
#  'adore': 975,
#  'cuter': 976,
#  'pencil': 977,
#  'originally': 978,
#  'twice': 979,
#  'flatter': 980,
#  'flowers': 981,
#  'given': 982,
#  'covers': 983,
#  'section': 984,
#  'shoes': 985,
#  'evening': 986,
#  'petites': 987,
#  'shrunk': 988,
#  'structured': 989,
#  'chose': 990,
#  'slit': 991,
#  'stated': 992,
#  'oh': 993,
#  'sent': 994,
#  'xsp': 995,
#  'styles': 996,
#  'layers': 997,
#  'picked': 998,
#  'snag': 999,
#  'okay': 1000,
#  ...}

# %%
# Find the size of the vocabulary
vocab_length = len(tokenizer.word_index) + 1
print("Vocab Length:", vocab_length)
# Out:
# Vocab Length: 12751

# %%
# Convert review texts into sequences of integers
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
# Find the maximum sequence length
max_seq_length = max(list(map(lambda x: len(x), X_train)))
print("Maximum Sequence Length: ", max_seq_length)
# Out:
# Maximum Sequence Length:  116

# %%
# Pad the sequences to be of uniform length
X_train = pad_sequences(X_train, maxlen=max_seq_length, padding='post')
X_test = pad_sequences(X_test, maxlen=max_seq_length, padding='post')

# %%
X_train
# Out:
# array([[  7,  18,   6, ...,   0,   0,   0],
#        [  1,  26,  15, ...,   0,   0,   0],
#        [  2,  74,   7, ...,   0,   0,   0],
#        ...,
#        [349,  23,  52, ...,   0,   0,   0],
#        [  2,  50,  28, ...,   0,   0,   0],
#        [ 22, 515,  22, ...,   0,   0,   0]],
#       shape=(15848, 116), dtype=int32)

# %%
X_test
# Out:
# array([[  36, 1080,    7, ...,    0,    0,    0],
#        [   2,  141,    7, ...,    0,    0,    0],
#        [ 261,    9,   22, ...,    0,    0,    0],
#        ...,
#        [   2,   92,    1, ...,    0,    0,    0],
#        [  52,  185,    1, ...,    0,    0,    0],
#        [  39,  141,    7, ...,    0,    0,    0]],
#       shape=(6793, 116), dtype=int32)

# %% [markdown]
# ### Training

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))

x = tf.keras.layers.Embedding(
    input_dim = vocab_length,
    output_dim = 128,
    input_length = max_seq_length
)(inputs)

# %%
inputs
# Out:
# <KerasTensor shape=(None, 116), dtype=float32, sparse=False, ragged=False, name=keras_tensor_17>

# %%
x
# Out:
# <KerasTensor shape=(None, 116, 128), dtype=float32, sparse=False, ragged=False, name=keras_tensor_18>

# %%
x = tf.keras.layers.Flatten()(x)

# %%
x
# Out:
# <KerasTensor shape=(None, 14848), dtype=float32, sparse=False, ragged=False, name=keras_tensor_19>

# %%
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 116)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_4 (Embedding)         │ (None, 116, 128)       │     1,632,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 14848)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │        14,849 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,646,977 (6.28 MB)
#  Trainable params: 1,646,977 (6.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.7133 - loss: 0.5601 - val_accuracy: 0.7808 - val_loss: 0.4696
# Epoch 2/100
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8561 - loss: 0.3508 - val_accuracy: 0.7804 - val_loss: 0.4737
# Epoch 3/100
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9372 - loss: 0.1979 - val_accuracy: 0.7842 - val_loss: 0.4932
# Epoch 4/100
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9769 - loss: 0.1003 - val_accuracy: 0.7713 - val_loss: 0.5450

# %% [markdown]
# ### Results

# %%
model.evaluate(X_test, y_test)
# Out:
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7842 - loss: 0.4709
# [0.47091054916381836, 0.7841895818710327]
